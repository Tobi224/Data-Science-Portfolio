# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('911.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df['zip'].value_counts().head(5)
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: count, dtype: int64

# %%
df['twp'].value_counts().head(5)
# Out:
# twp
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: count, dtype: int64

# %%
df['title'].nunique()
# Out:
# 110

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df['title'][0].split(':')
# Out:
# ['EMS', ' BACK PAINS/INJURY']

# %%
Reason = df['title'].apply(lambda x: x.split(':')[0])
df['Reason'] = Reason

# %%
df['Reason'].value_counts()
# Out:
# Reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Reason',hue='Reason')

plt.show()

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e Reason
# ...

# %%
s = df['timeStamp'][0]
type(s)
# Out:
# str

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %%
df['timeStamp'].iloc[0]
# Out:
# Timestamp('2015-12-10 17:40:00')

# %%
df['Hour'] = df['timeStamp'].apply(lambda x: x.hour)
df['Month'] = df['timeStamp'].apply(lambda x: x.month)
df['Day of Week'] = df['timeStamp'].apply(lambda x: x.day)

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day of Week']=df['Day of Week'].map(dmap)

# %%
sns.countplot(data=df,x=df['Day of Week'], hue='Reason',palette='viridis')
plt.legend(loc=[1.02,0.8])
plt.show()

# %%
sns.countplot(data=df,x='Month',hue='Reason',palette='viridis')
plt.legend(loc=(1.02,0.82))
plt.show()

# %%
byMonth = df.groupby(df['Month']).count()

# %%
byMonth.max()
# Out:
# lat            13205
# lng            13205
# desc           13205
# zip            11527
# title          13205
# timeStamp      13205
# twp            13203
# addr           13096
# e              13205
# Reason         13205
# Hour           13205
# Day of Week     2562
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.lineplot(data=byMonth,x='Month',y='twp')
plt.show()

# %%
byMonth['lat'].plot()
plt.show()

# %%
byMonth.head(1)
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
#
#        Reason   Hour  Day of Week
# Month
# 1       13205  13205         2206

# %%
sns.lmplot(data=byMonth.reset_index(),x='Month',y='twp')
plt.show()

# %%
df['Date'] = df['timeStamp'].apply(lambda x: x.date())

# %%
df['lat'].min()
# Out:
# nan

# %%
df
# Out:
# Empty DataFrame
# Columns: [lat, lng, desc, zip, title, timeStamp, twp, addr, e, Reason, Hour, Month, Day of Week, Date]
# Index: []

# %%
date = df.groupby('Date').count()

# %%
date.head()
# Out:
#             lat  lng  desc  zip  title  timeStamp  twp  addr    e  Reason  \
# Date
# 2015-12-10  115  115   115  100    115        115  115   113  115     115
# 2015-12-11  396  396   396  333    396        396  395   391  396     396
# 2015-12-12  403  403   403  333    403        403  403   401  403     403
# 2015-12-13  319  319   319  280    319        319  319   317  319     319
# 2015-12-14  447  447   447  387    447        447  446   445  447     447
#
#             Hour  Month  Day of Week
# Date
# 2015-12-10   115    115            0
# 2015-12-11   396    396            0
# 2015-12-12   403    403            0
# 2015-12-13   319    319            0
# 2015-12-14   447    447            0

# %%
sns.lineplot(data=date,x='Date',y='lat')
plt.tight_layout()
plt.show()

# %%
df.groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.show()

# %%
df.head(1)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
#
#        zip                   title           timeStamp          twp  \
# 0  19525.0  EMS: BACK PAINS/INJURY 2015-12-10 17:40:00  NEW HANOVER
#
#                      addr  e Reason  Hour  Month Day of Week        Date
# 0  REINDEER CT & DEAD END  1    EMS    17     12         NaN  2015-12-10

# %%
sns.lineplot(data=df,x=)
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# ...          ...        ...
# 99480  40.221227 -75.288737
# 99481  40.221227 -75.288737
# 99483  40.084465 -75.390173
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# 5      CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...  19446.0
# ...                                                  ...      ...
# 99480  SUMNEYTOWN PIKE & RR OVERPASS;  UPPER GWYNEDD;...      NaN
# 99481  SUMNEYTOWN PIKE & RR OVERPASS;  UPPER GWYNEDD;...      NaN
# ...

# %%
Traffic = df[df['Reason']=='Traffic']

# %%
Traffic = Traffic.groupby('Date').count()

# %%
sns.lineplot(data=Traffic,x='Date',y='twp')
plt.ylabel('')
plt.title('Traffic')
plt.show()

# %%
Fire.head(1)
# Out:
#             lat  lng  desc  zip  title  timeStamp  twp  addr   e  Reason  \
# Date
# 2015-12-10   15   15    15   13     15         15   15    15  15      15
#
#             Hour  Month  Day of Week
# Date
# 2015-12-10    15     15            0

# %%
Fire.head()
# Out:
#             lat  lng  desc  zip  title  timeStamp  twp  addr   e  Reason  \
# Date
# 2015-12-10   15   15    15   13     15         15   15    15  15      15
# 2015-12-11   69   69    69   59     69         69   68    68  69      69
# 2015-12-12   68   68    68   53     68         68   68    68  68      68
# 2015-12-13   51   51    51   48     51         51   51    51  51      51
# 2015-12-14   39   39    39   36     39         39   38    39  39      39
#
#             Hour  Month  Day of Week
# Date
# 2015-12-10    15     15            0
# 2015-12-11    69     69            0
# 2015-12-12    68     68            0
# 2015-12-13    51     51            0
# 2015-12-14    39     39            0

# %%
Fire = df[df['Reason'] == 'Fire'].groupby('Date').count()
sns.set_style('whitegrid')
sns.lineplot(data=Fire,x='Date',y='twp')
plt.ylabel('')
plt.title('Fire')

plt.show()

# %%
EMS = df[df['Reason']=='EMS'].groupby('Date').count()

# %%
EMS.head()
# Out:
#             lat  lng  desc  zip  title  timeStamp  twp  addr    e  Reason  \
# Date
# 2015-12-10   57   57    57   52     57         57   57    57   57      57
# 2015-12-11  186  186   186  166    186        186  186   186  186     186
# 2015-12-12  189  189   189  171    189        189  189   189  189     189
# 2015-12-13  190  190   190  178    190        190  190   190  190     190
# 2015-12-14  222  222   222  201    222        222  222   222  222     222
#
#             Hour  Month  Day of Week
# Date
# 2015-12-10    57     57            0
# 2015-12-11   186    186            0
# 2015-12-12   189    189            0
# 2015-12-13   190    190            0
# 2015-12-14   222    222            0

# %%
sns.lineplot(data=EMS,x='Date',y='twp')
plt.ylabel('')
plt.title('EMS')
plt.show()

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %%
df.groupby('Date').count()['lat']
# Out:
# Date
# 2015-12-10    115
# 2015-12-11    396
# 2015-12-12    403
# 2015-12-13    319
# 2015-12-14    447
#              ...
# 2016-08-20    328
# 2016-08-21    357
# 2016-08-22    389
# 2016-08-23    439
# 2016-08-24    132
# Name: lat, Length: 259, dtype: int64

# %%
t = df.groupby(by=['Day of Week','Hour']).count()['Reason'].unstack()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(t,cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(1.5,0.75))
sns.clustermap(t,cmap='viridis')
plt.show()

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %%
month = df.groupby(by=['Day of Week','Month']).count()['Reason'].unstack()
month.head()
# Out:
# Month          1    2    3    4    5    6    7    8
# Day of Week
# Fri          402  366  368  409  342  356  290  422
# Sat          448  402  297  334  362  307  392  422
# Sun          434  350  286  391  415  435  409  378
# Thu          324  433  368  586  361  431  309  403
# Tue          263  374  407  456  140  441  411  384

# %%
sns.heatmap(month,cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(3,1.5))
sns.clustermap(month,cmap='viridis')
plt.show()
