# %%
# Add at the beginning of your script
import os
import tensorflow as tf

# Enable memory growth to avoid memory fragmentation
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# Set to use mixed precision (significant speedup on newer GPUs)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Optional: Set TensorFlow to use only required memory
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4060 Laptop GPU, compute capability 8.9

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import sys
print("Python version:", sys.version)
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", len(tf.config.list_physical_devices('GPU')) > 0)
print("GPU Devices:", tf.config.list_physical_devices('GPU'))
# Out:
# Python version: 3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]
# TensorFlow version: 2.10.0
# GPU Available: True
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  benign_0__mal_1          569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# area error               569.0   40.337079   45.491006    6.802000
# smoothness error         569.0    0.007041    0.003003    0.001713
# compactness error        569.0    0.025478    0.017908    0.002252
# concavity error          569.0    0.031894    0.030186    0.000000
# concave points error     569.0    0.011796    0.006170    0.000000
# symmetry error           569.0    0.020542    0.008266    0.007882
# fractal dimension error  569.0    0.003795    0.002646    0.000895
# worst radius             569.0   16.269190    4.833242    7.930000
# worst texture            569.0   25.677223    6.146258   12.020000
# worst perimeter          569.0  107.261213   33.602542   50.410000
# worst area               569.0  880.583128  569.356993  185.200000
# worst smoothness         569.0    0.132369    0.022832    0.071170
# worst compactness        569.0    0.254265    0.157336    0.027290
# worst concavity          569.0    0.272188    0.208624    0.000000
# worst concave points     569.0    0.114606    0.065732    0.000000
# worst symmetry           569.0    0.290076    0.061867    0.156500
# worst fractal dimension  569.0    0.083946    0.018061    0.055040
# benign_0__mal_1          569.0    0.627417    0.483918    0.000000
#
#                                 25%         50%          75%         max
# mean radius               11.700000   13.370000    15.780000    28.11000
# mean texture              16.170000   18.840000    21.800000    39.28000
# mean perimeter            75.170000   86.240000   104.100000   188.50000
# mean area                420.300000  551.100000   782.700000  2501.00000
# mean smoothness            0.086370    0.095870     0.105300     0.16340
# mean compactness           0.064920    0.092630     0.130400     0.34540
# mean concavity             0.029560    0.061540     0.130700     0.42680
# mean concave points        0.020310    0.033500     0.074000     0.20120
# mean symmetry              0.161900    0.179200     0.195700     0.30400
# mean fractal dimension     0.057700    0.061540     0.066120     0.09744
# radius error               0.232400    0.324200     0.478900     2.87300
# texture error              0.833900    1.108000     1.474000     4.88500
# perimeter error            1.606000    2.287000     3.357000    21.98000
# area error                17.850000   24.530000    45.190000   542.20000
# smoothness error           0.005169    0.006380     0.008146     0.03113
# compactness error          0.013080    0.020450     0.032450     0.13540
# concavity error            0.015090    0.025890     0.042050     0.39600
# concave points error       0.007638    0.010930     0.014710     0.05279
# symmetry error             0.015160    0.018730     0.023480     0.07895
# fractal dimension error    0.002248    0.003187     0.004558     0.02984
# worst radius              13.010000   14.970000    18.790000    36.04000
# worst texture             21.080000   25.410000    29.720000    49.54000
# worst perimeter           84.110000   97.660000   125.400000   251.20000
# worst area               515.300000  686.500000  1084.000000  4254.00000
# worst smoothness           0.116600    0.131300     0.146000     0.22260
# worst compactness          0.147200    0.211900     0.339100     1.05800
# worst concavity            0.114500    0.226700     0.382900     1.25200
# worst concave points       0.064930    0.099930     0.161400     0.29100
# worst symmetry             0.250400    0.282200     0.317900     0.66380
# worst fractal dimension    0.071460    0.080040     0.092080     0.20750
# benign_0__mal_1            0.000000    1.000000     1.000000     1.00000

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <Axes: xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      benign_0__mal_1
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 564                0
# 565                0
# 566                0
# 567                0
# 568                1
#
# [569 rows x 31 columns]

# %%
X = df.drop('benign_0__mal_1',axis=1).values

# %%
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=101, test_size=0.25)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))

model.add(Dense(15,activation='relu'))

# BINARY CLASSIFICATION
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test,y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 7s 44ms/step - loss: 0.6856 - val_loss: 0.6782
# Epoch 2/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6638 - val_loss: 0.6586
# Epoch 3/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6406 - val_loss: 0.6319
# Epoch 4/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6103 - val_loss: 0.5977
# Epoch 5/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5722 - val_loss: 0.5565
# Epoch 6/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5265 - val_loss: 0.5057
# Epoch 7/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4772 - val_loss: 0.4529
# Epoch 8/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4239 - val_loss: 0.4021
# Epoch 9/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3769 - val_loss: 0.3515
# Epoch 10/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3352 - val_loss: 0.3116
# Epoch 11/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2979 - val_loss: 0.2744
# Epoch 12/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2674 - val_loss: 0.2470
# Epoch 13/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2460 - val_loss: 0.2218
# Epoch 14/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2239 - val_loss: 0.2035
# Epoch 15/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2040 - val_loss: 0.1848
# Epoch 16/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1885 - val_loss: 0.1714
# Epoch 17/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1753 - val_loss: 0.1584
# Epoch 18/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1658 - val_loss: 0.1506
# Epoch 19/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1531 - val_loss: 0.1418
# Epoch 20/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1448 - val_loss: 0.1362
# Epoch 21/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1365 - val_loss: 0.1367
# Epoch 22/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1311 - val_loss: 0.1267
# Epoch 23/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1243 - val_loss: 0.1211
# Epoch 24/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1194 - val_loss: 0.1222
# Epoch 25/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1109 - val_loss: 0.1138
# Epoch 26/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1070 - val_loss: 0.1161
# Epoch 27/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1024 - val_loss: 0.1099
# Epoch 28/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0996 - val_loss: 0.1065
# Epoch 29/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0970 - val_loss: 0.1116
# Epoch 30/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0978 - val_loss: 0.1074
# Epoch 31/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0932 - val_loss: 0.1038
# Epoch 32/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0882 - val_loss: 0.1044
# Epoch 33/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0843 - val_loss: 0.1100
# Epoch 34/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0818 - val_loss: 0.1001
# Epoch 35/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0796 - val_loss: 0.1091
# Epoch 36/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0841 - val_loss: 0.0973
# Epoch 37/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0822 - val_loss: 0.1063
# Epoch 38/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0739 - val_loss: 0.0973
# Epoch 39/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0742 - val_loss: 0.0993
# Epoch 40/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0779 - val_loss: 0.0950
# Epoch 41/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0752 - val_loss: 0.0998
# Epoch 42/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0698 - val_loss: 0.0961
# Epoch 43/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0695 - val_loss: 0.1013
# Epoch 44/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0680 - val_loss: 0.0934
# Epoch 45/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0676 - val_loss: 0.1034
# Epoch 46/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0667 - val_loss: 0.0968
# Epoch 47/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0657 - val_loss: 0.1026
# Epoch 48/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0645 - val_loss: 0.0929
# Epoch 49/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0669 - val_loss: 0.0981
# Epoch 50/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0640 - val_loss: 0.1001
# Epoch 51/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0623 - val_loss: 0.0970
# Epoch 52/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0634 - val_loss: 0.1005
# Epoch 53/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0621 - val_loss: 0.0939
# Epoch 54/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0601 - val_loss: 0.1039
# Epoch 55/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0616 - val_loss: 0.0938
# Epoch 56/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0611 - val_loss: 0.0999
# Epoch 57/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0595 - val_loss: 0.0963
# Epoch 58/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0616 - val_loss: 0.1016
# Epoch 59/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0588 - val_loss: 0.0942
# Epoch 60/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0609 - val_loss: 0.1052
# Epoch 61/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0570 - val_loss: 0.0977
# Epoch 62/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0592 - val_loss: 0.1055
# Epoch 63/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0589 - val_loss: 0.0981
# Epoch 64/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0568 - val_loss: 0.0980
# Epoch 65/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0563 - val_loss: 0.1020
# Epoch 66/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0581 - val_loss: 0.0971
# Epoch 67/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0573 - val_loss: 0.1016
# Epoch 68/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0554 - val_loss: 0.1050
# Epoch 69/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0544 - val_loss: 0.1017
# Epoch 70/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0547 - val_loss: 0.1008
# Epoch 71/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0544 - val_loss: 0.1032
# Epoch 72/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0544 - val_loss: 0.1032
# Epoch 73/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0533 - val_loss: 0.1121
# Epoch 74/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0554 - val_loss: 0.0998
# Epoch 75/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0523 - val_loss: 0.1084
# Epoch 76/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0526 - val_loss: 0.1011
# Epoch 77/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0548 - val_loss: 0.1076
# Epoch 78/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0543 - val_loss: 0.1075
# Epoch 79/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0543 - val_loss: 0.1055
# Epoch 80/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0525 - val_loss: 0.1034
# Epoch 81/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0511 - val_loss: 0.1077
# Epoch 82/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0532 - val_loss: 0.1006
# Epoch 83/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0540 - val_loss: 0.1056
# Epoch 84/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0506 - val_loss: 0.1034
# Epoch 85/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0510 - val_loss: 0.1077
# Epoch 86/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0514 - val_loss: 0.1045
# Epoch 87/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0536 - val_loss: 0.1048
# Epoch 88/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0528 - val_loss: 0.1030
# Epoch 89/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0526 - val_loss: 0.1034
# Epoch 90/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0503 - val_loss: 0.1101
# Epoch 91/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0504 - val_loss: 0.1048
# Epoch 92/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0506 - val_loss: 0.1129
# Epoch 93/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0504 - val_loss: 0.1106
# Epoch 94/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0502 - val_loss: 0.1144
# Epoch 95/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0503 - val_loss: 0.1103
# Epoch 96/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0493 - val_loss: 0.1179
# Epoch 97/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0511 - val_loss: 0.1084
# Epoch 98/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0501 - val_loss: 0.1144
# Epoch 99/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0521 - val_loss: 0.1118
# Epoch 100/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0488 - val_loss: 0.1061
# Epoch 101/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0492 - val_loss: 0.1105
# Epoch 102/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0479 - val_loss: 0.1117
# Epoch 103/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0482 - val_loss: 0.1097
# Epoch 104/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0487 - val_loss: 0.1181
# Epoch 105/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0485 - val_loss: 0.1150
# Epoch 106/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0467 - val_loss: 0.1163
# Epoch 107/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0483 - val_loss: 0.1202
# Epoch 108/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0464 - val_loss: 0.1074
# Epoch 109/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0469 - val_loss: 0.1192
# Epoch 110/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0466 - val_loss: 0.1090
# Epoch 111/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0480 - val_loss: 0.1129
# Epoch 112/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0465 - val_loss: 0.1146
# Epoch 113/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0469 - val_loss: 0.1186
# Epoch 114/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0468 - val_loss: 0.1202
# Epoch 115/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0476 - val_loss: 0.1069
# Epoch 116/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0471 - val_loss: 0.1244
# Epoch 117/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0519 - val_loss: 0.1159
# Epoch 118/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0527 - val_loss: 0.1089
# Epoch 119/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0537 - val_loss: 0.1236
# Epoch 120/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0446 - val_loss: 0.1123
# Epoch 121/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0453 - val_loss: 0.1128
# Epoch 122/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0474 - val_loss: 0.1176
# Epoch 123/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0472 - val_loss: 0.1159
# Epoch 124/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0466 - val_loss: 0.1207
# Epoch 125/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0455 - val_loss: 0.1163
# Epoch 126/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.1264
# Epoch 127/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0445 - val_loss: 0.1191
# Epoch 128/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.1179
# Epoch 129/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0461 - val_loss: 0.1238
# Epoch 130/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0464 - val_loss: 0.1165
# Epoch 131/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0449 - val_loss: 0.1388
# Epoch 132/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0464 - val_loss: 0.1219
# Epoch 133/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0426 - val_loss: 0.1266
# Epoch 134/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.1146
# Epoch 135/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0456 - val_loss: 0.1324
# Epoch 136/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0435 - val_loss: 0.1182
# Epoch 137/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0424 - val_loss: 0.1240
# Epoch 138/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0447 - val_loss: 0.1269
# Epoch 139/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.1192
# Epoch 140/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0475 - val_loss: 0.1257
# Epoch 141/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0431 - val_loss: 0.1209
# Epoch 142/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0427 - val_loss: 0.1238
# Epoch 143/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0415 - val_loss: 0.1230
# Epoch 144/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.1277
# Epoch 145/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0422 - val_loss: 0.1215
# Epoch 146/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0416 - val_loss: 0.1182
# Epoch 147/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.1363
# Epoch 148/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0468 - val_loss: 0.1238
# Epoch 149/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0432 - val_loss: 0.1258
# Epoch 150/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0457 - val_loss: 0.1280
# Epoch 151/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0401 - val_loss: 0.1257
# Epoch 152/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0418 - val_loss: 0.1309
# Epoch 153/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0399 - val_loss: 0.1238
# Epoch 154/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0398 - val_loss: 0.1293
# Epoch 155/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0407 - val_loss: 0.1216
# Epoch 156/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0400 - val_loss: 0.1358
# Epoch 157/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0392 - val_loss: 0.1207
# Epoch 158/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0411 - val_loss: 0.1262
# Epoch 159/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.1308
# Epoch 160/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0396 - val_loss: 0.1285
# Epoch 161/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0409 - val_loss: 0.1276
# Epoch 162/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0409 - val_loss: 0.1226
# Epoch 163/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0399 - val_loss: 0.1284
# Epoch 164/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0394 - val_loss: 0.1342
# Epoch 165/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0514 - val_loss: 0.1161
# Epoch 166/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0428 - val_loss: 0.1380
# Epoch 167/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0420 - val_loss: 0.1404
# Epoch 168/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0399 - val_loss: 0.1243
# Epoch 169/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0396 - val_loss: 0.1237
# Epoch 170/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.1365
# Epoch 171/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0392 - val_loss: 0.1209
# Epoch 172/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0400 - val_loss: 0.1398
# Epoch 173/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0454 - val_loss: 0.1336
# Epoch 174/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0376 - val_loss: 0.1275
# Epoch 175/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0373 - val_loss: 0.1361
# Epoch 176/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0374 - val_loss: 0.1292
# Epoch 177/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0382 - val_loss: 0.1399
# Epoch 178/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0388 - val_loss: 0.1355
# Epoch 179/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0391 - val_loss: 0.1298
# Epoch 180/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0432 - val_loss: 0.1279
# Epoch 181/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0439 - val_loss: 0.1482
# Epoch 182/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0400 - val_loss: 0.1377
# Epoch 183/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0363 - val_loss: 0.1290
# Epoch 184/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0363 - val_loss: 0.1418
# Epoch 185/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0402 - val_loss: 0.1467
# Epoch 186/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0447 - val_loss: 0.1292
# Epoch 187/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0379 - val_loss: 0.1376
# Epoch 188/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0364 - val_loss: 0.1412
# Epoch 189/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0368 - val_loss: 0.1363
# Epoch 190/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0360 - val_loss: 0.1413
# Epoch 191/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0358 - val_loss: 0.1358
# Epoch 192/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0378 - val_loss: 0.1428
# Epoch 193/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0430 - val_loss: 0.1246
# Epoch 194/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0389 - val_loss: 0.1369
# Epoch 195/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0366 - val_loss: 0.1387
# Epoch 196/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0361 - val_loss: 0.1304
# Epoch 197/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0395 - val_loss: 0.1543
# Epoch 198/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0414 - val_loss: 0.1262
# Epoch 199/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0368 - val_loss: 0.1603
# Epoch 200/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0385 - val_loss: 0.1290
# Epoch 201/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0353 - val_loss: 0.1451
# Epoch 202/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0340 - val_loss: 0.1349
# Epoch 203/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0345 - val_loss: 0.1476
# Epoch 204/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0340 - val_loss: 0.1375
# Epoch 205/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0351 - val_loss: 0.1601
# Epoch 206/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0384 - val_loss: 0.1375
# Epoch 207/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0373 - val_loss: 0.1323
# Epoch 208/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0363 - val_loss: 0.1435
# Epoch 209/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0357 - val_loss: 0.1304
# Epoch 210/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0364 - val_loss: 0.1636
# Epoch 211/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0355 - val_loss: 0.1307
# Epoch 212/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0364 - val_loss: 0.1378
# Epoch 213/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0341 - val_loss: 0.1341
# Epoch 214/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0396 - val_loss: 0.1602
# Epoch 215/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0335 - val_loss: 0.1386
# Epoch 216/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0361 - val_loss: 0.1414
# Epoch 217/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0335 - val_loss: 0.1383
# Epoch 218/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0325 - val_loss: 0.1437
# Epoch 219/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0328 - val_loss: 0.1434
# Epoch 220/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0333 - val_loss: 0.1434
# Epoch 221/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0324 - val_loss: 0.1505
# Epoch 222/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0322 - val_loss: 0.1428
# Epoch 223/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0321 - val_loss: 0.1458
# Epoch 224/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0400 - val_loss: 0.1292
# Epoch 225/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0353 - val_loss: 0.1504
# Epoch 226/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0330 - val_loss: 0.1353
# Epoch 227/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0307 - val_loss: 0.1593
# Epoch 228/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0351 - val_loss: 0.1388
# Epoch 229/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0320 - val_loss: 0.1423
# Epoch 230/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0328 - val_loss: 0.1431
# Epoch 231/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0362 - val_loss: 0.1574
# Epoch 232/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0319 - val_loss: 0.1512
# Epoch 233/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0317 - val_loss: 0.1527
# Epoch 234/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0310 - val_loss: 0.1439
# Epoch 235/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0327 - val_loss: 0.1455
# Epoch 236/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0325 - val_loss: 0.1494
# Epoch 237/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0308 - val_loss: 0.1406
# Epoch 238/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0301 - val_loss: 0.1548
# Epoch 239/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0293 - val_loss: 0.1370
# Epoch 240/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0306 - val_loss: 0.1607
# Epoch 241/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0337 - val_loss: 0.1425
# Epoch 242/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0296 - val_loss: 0.1486
# Epoch 243/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0306 - val_loss: 0.1500
# Epoch 244/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0331 - val_loss: 0.1466
# Epoch 245/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0314 - val_loss: 0.1568
# Epoch 246/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0307 - val_loss: 0.1509
# Epoch 247/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0299 - val_loss: 0.1671
# Epoch 248/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0310 - val_loss: 0.1532
# Epoch 249/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0320 - val_loss: 0.1539
# Epoch 250/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0292 - val_loss: 0.1520
# Epoch 251/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0288 - val_loss: 0.1415
# Epoch 252/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0286 - val_loss: 0.1587
# Epoch 253/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0292 - val_loss: 0.1522
# Epoch 254/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0307 - val_loss: 0.1477
# Epoch 255/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.1546
# Epoch 256/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0346 - val_loss: 0.1379
# Epoch 257/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0327 - val_loss: 0.1658
# Epoch 258/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0320 - val_loss: 0.1448
# Epoch 259/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0291 - val_loss: 0.1593
# Epoch 260/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0376 - val_loss: 0.1393
# Epoch 261/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0271 - val_loss: 0.1808
# Epoch 262/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0316 - val_loss: 0.1429
# Epoch 263/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0278 - val_loss: 0.1593
# Epoch 264/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0276 - val_loss: 0.1514
# Epoch 265/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0288 - val_loss: 0.1835
# Epoch 266/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0280 - val_loss: 0.1459
# Epoch 267/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0303 - val_loss: 0.1579
# Epoch 268/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0282 - val_loss: 0.1597
# Epoch 269/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0273 - val_loss: 0.1617
# Epoch 270/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0309 - val_loss: 0.1834
# Epoch 271/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0308 - val_loss: 0.1497
# Epoch 272/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.1870
# Epoch 273/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0274 - val_loss: 0.1446
# Epoch 274/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0294 - val_loss: 0.1701
# Epoch 275/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0269 - val_loss: 0.1553
# Epoch 276/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0275 - val_loss: 0.1564
# Epoch 277/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0274 - val_loss: 0.1494
# Epoch 278/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0268 - val_loss: 0.1639
# Epoch 279/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0271 - val_loss: 0.1661
# Epoch 280/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0289 - val_loss: 0.1671
# Epoch 281/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0263 - val_loss: 0.1615
# Epoch 282/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0254 - val_loss: 0.1648
# Epoch 283/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0269 - val_loss: 0.1574
# Epoch 284/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0270 - val_loss: 0.1504
# Epoch 285/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0270 - val_loss: 0.1667
# Epoch 286/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0260 - val_loss: 0.1643
# Epoch 287/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0256 - val_loss: 0.1623
# Epoch 288/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0248 - val_loss: 0.1529
# Epoch 289/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0250 - val_loss: 0.1793
# Epoch 290/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0260 - val_loss: 0.1662
# Epoch 291/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0245 - val_loss: 0.1630
# Epoch 292/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0248 - val_loss: 0.1690
# Epoch 293/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0249 - val_loss: 0.1606
# Epoch 294/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0250 - val_loss: 0.1652
# Epoch 295/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0241 - val_loss: 0.1630
# Epoch 296/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0257 - val_loss: 0.1638
# Epoch 297/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0262 - val_loss: 0.1790
# Epoch 298/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0277 - val_loss: 0.1869
# Epoch 299/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0319 - val_loss: 0.1543
# Epoch 300/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0268 - val_loss: 0.1762
# Epoch 301/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.1604
# Epoch 302/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0239 - val_loss: 0.1718
# Epoch 303/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0240 - val_loss: 0.1574
# Epoch 304/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0260 - val_loss: 0.1947
# Epoch 305/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0259 - val_loss: 0.1625
# Epoch 306/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0230 - val_loss: 0.1840
# Epoch 307/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0243 - val_loss: 0.1608
# Epoch 308/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0233 - val_loss: 0.1828
# Epoch 309/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0248 - val_loss: 0.1599
# Epoch 310/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0292 - val_loss: 0.1950
# Epoch 311/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0246 - val_loss: 0.1685
# Epoch 312/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0218 - val_loss: 0.1884
# Epoch 313/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0247 - val_loss: 0.1538
# Epoch 314/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.1898
# Epoch 315/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0235 - val_loss: 0.1601
# Epoch 316/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0243 - val_loss: 0.1819
# Epoch 317/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0279 - val_loss: 0.1996
# Epoch 318/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0261 - val_loss: 0.1670
# Epoch 319/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0269 - val_loss: 0.2064
# Epoch 320/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0242 - val_loss: 0.1630
# Epoch 321/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.1788
# Epoch 322/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0220 - val_loss: 0.1814
# Epoch 323/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.1633
# Epoch 324/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0237 - val_loss: 0.1665
# Epoch 325/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0228 - val_loss: 0.1726
# Epoch 326/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0219 - val_loss: 0.1713
# Epoch 327/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0219 - val_loss: 0.1629
# Epoch 328/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0263 - val_loss: 0.2337
# Epoch 329/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0261 - val_loss: 0.1562
# Epoch 330/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.1976
# Epoch 331/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0209 - val_loss: 0.1748
# Epoch 332/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0209 - val_loss: 0.1819
# Epoch 333/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0228 - val_loss: 0.1673
# Epoch 334/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0227 - val_loss: 0.1799
# Epoch 335/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0222 - val_loss: 0.1872
# Epoch 336/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0234 - val_loss: 0.1799
# Epoch 337/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.1696
# Epoch 338/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0221 - val_loss: 0.1877
# Epoch 339/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0215 - val_loss: 0.1919
# Epoch 340/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0218 - val_loss: 0.1798
# Epoch 341/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0217 - val_loss: 0.1915
# Epoch 342/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0198 - val_loss: 0.1803
# Epoch 343/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0195 - val_loss: 0.1832
# Epoch 344/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.1838
# Epoch 345/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0209 - val_loss: 0.1842
# Epoch 346/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.1783
# Epoch 347/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.1894
# Epoch 348/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.1768
# Epoch 349/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0231 - val_loss: 0.1999
# Epoch 350/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0198 - val_loss: 0.1915
# Epoch 351/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0208 - val_loss: 0.1859
# Epoch 352/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0257 - val_loss: 0.2385
# Epoch 353/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0205 - val_loss: 0.1662
# Epoch 354/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0208 - val_loss: 0.2111
# Epoch 355/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0267 - val_loss: 0.2054
# Epoch 356/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0233 - val_loss: 0.1841
# Epoch 357/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0187 - val_loss: 0.1894
# Epoch 358/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.1789
# Epoch 359/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0181 - val_loss: 0.1900
# Epoch 360/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0179 - val_loss: 0.1850
# Epoch 361/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0189 - val_loss: 0.2094
# Epoch 362/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0198 - val_loss: 0.1944
# Epoch 363/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0190 - val_loss: 0.1731
# Epoch 364/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0209 - val_loss: 0.2094
# Epoch 365/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.1944
# Epoch 366/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0184 - val_loss: 0.1876
# Epoch 367/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0196 - val_loss: 0.2209
# Epoch 368/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0184 - val_loss: 0.1894
# Epoch 369/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0183 - val_loss: 0.1835
# Epoch 370/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0200 - val_loss: 0.1965
# Epoch 371/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0199 - val_loss: 0.2173
# Epoch 372/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0181 - val_loss: 0.1793
# Epoch 373/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0193 - val_loss: 0.2025
# Epoch 374/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0180 - val_loss: 0.2125
# Epoch 375/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.1909
# Epoch 376/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0207 - val_loss: 0.1768
# Epoch 377/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0225 - val_loss: 0.2279
# Epoch 378/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0214 - val_loss: 0.2141
# Epoch 379/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0177 - val_loss: 0.2000
# Epoch 380/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.2021
# Epoch 381/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0174 - val_loss: 0.2056
# Epoch 382/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0160 - val_loss: 0.1958
# Epoch 383/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.1971
# Epoch 384/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0175 - val_loss: 0.2373
# Epoch 385/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0163 - val_loss: 0.1860
# Epoch 386/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0176 - val_loss: 0.2166
# Epoch 387/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0163 - val_loss: 0.2077
# Epoch 388/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0218 - val_loss: 0.1817
# Epoch 389/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0198 - val_loss: 0.2525
# Epoch 390/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0195 - val_loss: 0.1952
# Epoch 391/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.2086
# Epoch 392/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.2371
# Epoch 393/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0171 - val_loss: 0.1959
# Epoch 394/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.2476
# Epoch 395/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0172 - val_loss: 0.1984
# Epoch 396/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.2148
# Epoch 397/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.2307
# Epoch 398/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0160 - val_loss: 0.2025
# Epoch 399/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.2013
# Epoch 400/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0168 - val_loss: 0.1951
# Epoch 401/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0160 - val_loss: 0.2492
# Epoch 402/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0296 - val_loss: 0.1914
# Epoch 403/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0281 - val_loss: 0.1947
# Epoch 404/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0250 - val_loss: 0.2442
# Epoch 405/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0193 - val_loss: 0.1947
# Epoch 406/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0154 - val_loss: 0.2128
# Epoch 407/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0159 - val_loss: 0.1897
# Epoch 408/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0164 - val_loss: 0.2265
# Epoch 409/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.2004
# Epoch 410/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0149 - val_loss: 0.2112
# Epoch 411/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0150 - val_loss: 0.2225
# Epoch 412/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0143 - val_loss: 0.2142
# Epoch 413/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.2063
# Epoch 414/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0139 - val_loss: 0.2192
# Epoch 415/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0152 - val_loss: 0.2329
# Epoch 416/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0174 - val_loss: 0.2099
# Epoch 417/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.2076
# Epoch 418/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0141 - val_loss: 0.2200
# Epoch 419/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0136 - val_loss: 0.2098
# Epoch 420/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0141 - val_loss: 0.2386
# Epoch 421/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0142 - val_loss: 0.2100
# Epoch 422/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.2181
# Epoch 423/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.2341
# Epoch 424/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.2203
# Epoch 425/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0138 - val_loss: 0.2158
# Epoch 426/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0154 - val_loss: 0.2410
# Epoch 427/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0137 - val_loss: 0.2170
# Epoch 428/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0139 - val_loss: 0.2266
# Epoch 429/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0129 - val_loss: 0.2194
# Epoch 430/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0148 - val_loss: 0.2202
# Epoch 431/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0148 - val_loss: 0.2361
# Epoch 432/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.2205
# Epoch 433/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0130 - val_loss: 0.2410
# Epoch 434/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0135 - val_loss: 0.2420
# Epoch 435/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0127 - val_loss: 0.2241
# Epoch 436/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.2320
# Epoch 437/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.2371
# Epoch 438/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.2031
# Epoch 439/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0179 - val_loss: 0.2773
# Epoch 440/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0162 - val_loss: 0.2130
# Epoch 441/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0143 - val_loss: 0.2359
# Epoch 442/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0123 - val_loss: 0.2174
# Epoch 443/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0130 - val_loss: 0.2451
# Epoch 444/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.2088
# Epoch 445/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.2382
# Epoch 446/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.2287
# Epoch 447/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.2325
# Epoch 448/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0126 - val_loss: 0.2343
# Epoch 449/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0147 - val_loss: 0.2127
# Epoch 450/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0162 - val_loss: 0.2850
# Epoch 451/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0143 - val_loss: 0.2384
# Epoch 452/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0131 - val_loss: 0.2439
# Epoch 453/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0128 - val_loss: 0.2415
# Epoch 454/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0118 - val_loss: 0.2311
# Epoch 455/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.2549
# Epoch 456/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.2270
# Epoch 457/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.2760
# Epoch 458/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0130 - val_loss: 0.2397
# Epoch 459/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0127 - val_loss: 0.2545
# Epoch 460/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.2683
# Epoch 461/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0126 - val_loss: 0.2430
# Epoch 462/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0121 - val_loss: 0.2391
# Epoch 463/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.2979
# Epoch 464/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0237 - val_loss: 0.3108
# Epoch 465/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0202 - val_loss: 0.2189
# Epoch 466/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0115 - val_loss: 0.2616
# Epoch 467/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.2443
# Epoch 468/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0110 - val_loss: 0.2388
# Epoch 469/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0121 - val_loss: 0.2567
# Epoch 470/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.2501
# Epoch 471/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.2317
# Epoch 472/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.2493
# Epoch 473/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0111 - val_loss: 0.2659
# Epoch 474/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0111 - val_loss: 0.2347
# Epoch 475/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0129 - val_loss: 0.2445
# Epoch 476/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0117 - val_loss: 0.2629
# Epoch 477/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0142 - val_loss: 0.2308
# Epoch 478/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0116 - val_loss: 0.2627
# Epoch 479/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0107 - val_loss: 0.2568
# Epoch 480/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0101 - val_loss: 0.2414
# Epoch 481/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.2611
# Epoch 482/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0096 - val_loss: 0.2425
# Epoch 483/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.2963
# Epoch 484/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0126 - val_loss: 0.2382
# Epoch 485/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.2579
# Epoch 486/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0104 - val_loss: 0.2612
# Epoch 487/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0106 - val_loss: 0.2573
# Epoch 488/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0100 - val_loss: 0.2522
# Epoch 489/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0106 - val_loss: 0.2784
# Epoch 490/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.2495
# Epoch 491/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.2893
# Epoch 492/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.2539
# Epoch 493/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.3017
# Epoch 494/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0160 - val_loss: 0.2821
# Epoch 495/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0147 - val_loss: 0.2463
# Epoch 496/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0091 - val_loss: 0.2850
# Epoch 497/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.2590
# Epoch 498/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0111 - val_loss: 0.2732
# Epoch 499/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0096 - val_loss: 0.2654
# Epoch 500/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0095 - val_loss: 0.2664
# Epoch 501/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0100 - val_loss: 0.2894
# Epoch 502/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0092 - val_loss: 0.2500
# Epoch 503/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.2934
# Epoch 504/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0097 - val_loss: 0.2615
# Epoch 505/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0093 - val_loss: 0.2614
# Epoch 506/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0092 - val_loss: 0.2621
# Epoch 507/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.2930
# Epoch 508/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.2594
# Epoch 509/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.2737
# Epoch 510/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.2725
# Epoch 511/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0092 - val_loss: 0.2635
# Epoch 512/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.2847
# Epoch 513/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0091 - val_loss: 0.2748
# Epoch 514/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0098 - val_loss: 0.2462
# Epoch 515/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0142 - val_loss: 0.3955
# Epoch 516/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0145 - val_loss: 0.2695
# Epoch 517/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0093 - val_loss: 0.2881
# Epoch 518/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.2808
# Epoch 519/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.2564
# Epoch 520/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0102 - val_loss: 0.2666
# Epoch 521/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.2943
# Epoch 522/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.2955
# Epoch 523/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.2784
# Epoch 524/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0083 - val_loss: 0.2679
# Epoch 525/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.3072
# Epoch 526/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0098 - val_loss: 0.3015
# Epoch 527/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.2895
# Epoch 528/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0087 - val_loss: 0.3009
# Epoch 529/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.2800
# Epoch 530/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 0.2911
# Epoch 531/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.2796
# Epoch 532/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.2981
# Epoch 533/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.2739
# Epoch 534/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0078 - val_loss: 0.2992
# Epoch 535/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.2716
# Epoch 536/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.3163
# Epoch 537/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.2725
# Epoch 538/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.2962
# Epoch 539/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.3014
# Epoch 540/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.2962
# Epoch 541/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0084 - val_loss: 0.2693
# Epoch 542/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0086 - val_loss: 0.3177
# Epoch 543/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.2942
# Epoch 544/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.2585
# Epoch 545/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0134 - val_loss: 0.3714
# Epoch 546/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.2846
# Epoch 547/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.3153
# Epoch 548/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.2845
# Epoch 549/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.2992
# Epoch 550/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0078 - val_loss: 0.3455
# Epoch 551/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.2950
# Epoch 552/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 0.3347
# Epoch 553/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.2923
# Epoch 554/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 0.3201
# Epoch 555/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.3018
# Epoch 556/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.3227
# Epoch 557/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.3012
# Epoch 558/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.3054
# Epoch 559/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0068 - val_loss: 0.3021
# Epoch 560/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0075 - val_loss: 0.3519
# Epoch 561/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.3129
# Epoch 562/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.2797
# Epoch 563/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0111 - val_loss: 0.3598
# Epoch 564/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0153 - val_loss: 0.3834
# Epoch 565/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0102 - val_loss: 0.2914
# Epoch 566/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.3217
# Epoch 567/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0078 - val_loss: 0.2954
# Epoch 568/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.3421
# Epoch 569/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.3416
# Epoch 570/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.3138
# Epoch 571/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0128 - val_loss: 0.2765
# Epoch 572/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0091 - val_loss: 0.3835
# Epoch 573/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.2909
# Epoch 574/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.3263
# Epoch 575/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0064 - val_loss: 0.2957
# Epoch 576/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.3662
# Epoch 577/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0071 - val_loss: 0.2870
# Epoch 578/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0076 - val_loss: 0.3415
# Epoch 579/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0085 - val_loss: 0.3387
# Epoch 580/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0068 - val_loss: 0.3089
# Epoch 581/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0061 - val_loss: 0.3265
# Epoch 582/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.3248
# Epoch 583/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.3249
# Epoch 584/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.3496
# Epoch 585/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.2975
# Epoch 586/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.3527
# Epoch 587/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.3158
# Epoch 588/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.3271
# Epoch 589/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.3140
# Epoch 590/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.3706
# Epoch 591/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.3190
# Epoch 592/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.3231
# Epoch 593/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.3474
# Epoch 594/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.3228
# Epoch 595/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.3443
# Epoch 596/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.3536
# Epoch 597/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.3405
# Epoch 598/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.3234
# Epoch 599/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.3860
# Epoch 600/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.3113

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#          loss  val_loss
# 0    0.685636  0.678233
# 1    0.663774  0.658630
# 2    0.640552  0.631904
# 3    0.610258  0.597707
# 4    0.572220  0.556507
# ..        ...       ...
# 595  0.006977  0.353568
# 596  0.005679  0.340522
# 597  0.005672  0.323353
# 598  0.007081  0.385960
# 599  0.006701  0.311300
#
# [600 rows x 2 columns]

# %%
losses.plot()
# Out:
# <Axes: >

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))

model.add(Dense(15, activation='relu'))

#BINARY CLASSIFICATION
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
help(EarlyStopping)
# Out:
# Help on class EarlyStopping in module keras.callbacks:
#
# class EarlyStopping(Callback)
#  |  EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#  |
#  |  Stop training when a monitored metric has stopped improving.
#  |
#  |  Assuming the goal of a training is to minimize the loss. With this, the
#  |  metric to be monitored would be `'loss'`, and mode would be `'min'`. A
#  |  `model.fit()` training loop will check at end of every epoch whether
#  |  the loss is no longer decreasing, considering the `min_delta` and
#  |  `patience` if applicable. Once it's found no longer decreasing,
#  |  `model.stop_training` is marked True and the training terminates.
#  |
#  |  The quantity to be monitored needs to be available in `logs` dict.
#  |  To make it so, pass the loss or metrics at `model.compile()`.
#  |
#  |  Args:
#  |    monitor: Quantity to be monitored.
#  |    min_delta: Minimum change in the monitored quantity
#  |        to qualify as an improvement, i.e. an absolute
#  |        change of less than min_delta, will count as no
#  |        improvement.
#  |    patience: Number of epochs with no improvement
#  |        after which training will be stopped.
#  |    verbose: Verbosity mode, 0 or 1. Mode 0 is silent, and mode 1
#  |        displays messages when the callback takes an action.
#  |    mode: One of `{"auto", "min", "max"}`. In `min` mode,
#  |        training will stop when the quantity
#  |        monitored has stopped decreasing; in `"max"`
#  |        mode it will stop when the quantity
#  |        monitored has stopped increasing; in `"auto"`
#  |        mode, the direction is automatically inferred
#  |        from the name of the monitored quantity.
#  |    baseline: Baseline value for the monitored quantity.
#  |        Training will stop if the model doesn't show improvement over the
#  |        baseline.
#  |    restore_best_weights: Whether to restore model weights from
#  |        the epoch with the best value of the monitored quantity.
#  |        If False, the model weights obtained at the last step of
#  |        training are used. An epoch will be restored regardless
#  |        of the performance relative to the `baseline`. If no epoch
#  |        improves on `baseline`, training will run for `patience`
#  |        epochs and restore weights from the best epoch in that set.
#  |
#  |  Example:
#  |
#  |  >>> callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
#  |  >>> # This callback will stop the training when there is no improvement in
#  |  >>> # the loss for three consecutive epochs.
#  |  >>> model = tf.keras.models.Sequential([tf.keras.layers.Dense(10)])
#  |  >>> model.compile(tf.keras.optimizers.SGD(), loss='mse')
#  |  >>> history = model.fit(np.arange(100).reshape(5, 20), np.zeros(5),
#  |  ...                     epochs=10, batch_size=1, callbacks=[callback],
#  |  ...                     verbose=0)
#  |  >>> len(history.history['loss'])  # Only 4 epochs are run.
#  |  4
#  |
#  |  Method resolution order:
#  |      EarlyStopping
#  |      Callback
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_monitor_value(self, logs)
#  |
#  |  on_epoch_end(self, epoch, logs=None)
#  |      Called at the end of an epoch.
#  |
#  |      Subclasses should override for any actions to run. This function should
#  |      only be called during TRAIN mode.
#  |
#  |      Args:
#  |          epoch: Integer, index of epoch.
#  |          logs: Dict, metric results for this training epoch, and for the
#  |            validation epoch if validation is performed. Validation result
#  |            keys are prefixed with `val_`. For training epoch, the values of
#  |            the `Model`'s metrics are returned. Example:
#  |            `{'loss': 0.2, 'accuracy': 0.7}`.
#  |
#  |  on_train_begin(self, logs=None)
#  |      Called at the beginning of training.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_train_end(self, logs=None)
#  |      Called at the end of training.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently the output of the last call to
#  |            `on_epoch_end()` is passed to this argument for this method but
#  |            that may change in the future.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Callback:
#  |
#  |  on_batch_begin(self, batch, logs=None)
#  |      A backwards compatibility alias for `on_train_batch_begin`.
#  |
#  |  on_batch_end(self, batch, logs=None)
#  |      A backwards compatibility alias for `on_train_batch_end`.
#  |
#  |  on_epoch_begin(self, epoch, logs=None)
#  |      Called at the start of an epoch.
#  |
#  |      Subclasses should override for any actions to run. This function should
#  |      only be called during TRAIN mode.
#  |
#  |      Args:
#  |          epoch: Integer, index of epoch.
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_predict_batch_begin(self, batch, logs=None)
#  |      Called at the beginning of a batch in `predict` methods.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_predict_batch_end(self, batch, logs=None)
#  |      Called at the end of a batch in `predict` methods.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Aggregated metric results up until this batch.
#  |
#  |  on_predict_begin(self, logs=None)
#  |      Called at the beginning of prediction.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_predict_end(self, logs=None)
#  |      Called at the end of prediction.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_test_batch_begin(self, batch, logs=None)
#  |      Called at the beginning of a batch in `evaluate` methods.
#  |
#  |      Also called at the beginning of a validation batch in the `fit`
#  |      methods, if validation data is provided.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_test_batch_end(self, batch, logs=None)
#  |      Called at the end of a batch in `evaluate` methods.
#  |
#  |      Also called at the end of a validation batch in the `fit`
#  |      methods, if validation data is provided.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Aggregated metric results up until this batch.
#  |
#  |  on_test_begin(self, logs=None)
#  |      Called at the beginning of evaluation or validation.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_test_end(self, logs=None)
#  |      Called at the end of evaluation or validation.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Args:
#  |          logs: Dict. Currently the output of the last call to
#  |            `on_test_batch_end()` is passed to this argument for this method
#  |            but that may change in the future.
#  |
#  |  on_train_batch_begin(self, batch, logs=None)
#  |      Called at the beginning of a training batch in `fit` methods.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Currently no data is passed to this argument for this
#  |            method but that may change in the future.
#  |
#  |  on_train_batch_end(self, batch, logs=None)
#  |      Called at the end of a training batch in `fit` methods.
#  |
#  |      Subclasses should override for any actions to run.
#  |
#  |      Note that if the `steps_per_execution` argument to `compile` in
#  |      `tf.keras.Model` is set to `N`, this method will only be called every
#  |      `N` batches.
#  |
#  |      Args:
#  |          batch: Integer, index of batch within the current epoch.
#  |          logs: Dict. Aggregated metric results up until this batch.
#  |
#  |  set_model(self, model)
#  |
#  |  set_params(self, params)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Callback:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)#restore_best_weights=True

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 2s 33ms/step - loss: 0.6832 - val_loss: 0.6630
# Epoch 2/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6454 - val_loss: 0.6295
# Epoch 3/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.6086 - val_loss: 0.5895
# Epoch 4/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5633 - val_loss: 0.5383
# Epoch 5/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.5140 - val_loss: 0.4864
# Epoch 6/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4631 - val_loss: 0.4348
# Epoch 7/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4137 - val_loss: 0.3856
# Epoch 8/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3676 - val_loss: 0.3356
# Epoch 9/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3258 - val_loss: 0.2941
# Epoch 10/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2958 - val_loss: 0.2641
# Epoch 11/600
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2707 - val_loss: 0.2408
# Epoch 12/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2500 - val_loss: 0.2189
# Epoch 13/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2340 - val_loss: 0.2028
# Epoch 14/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2178 - val_loss: 0.1892
# Epoch 15/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2060 - val_loss: 0.1785
# Epoch 16/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1958 - val_loss: 0.1682
# Epoch 17/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1872 - val_loss: 0.1603
# Epoch 18/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1774 - val_loss: 0.1542
# Epoch 19/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1687 - val_loss: 0.1486
# Epoch 20/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1614 - val_loss: 0.1429
# Epoch 21/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1572 - val_loss: 0.1407
# Epoch 22/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1499 - val_loss: 0.1365
# Epoch 23/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1423 - val_loss: 0.1287
# Epoch 24/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1382 - val_loss: 0.1266
# Epoch 25/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1317 - val_loss: 0.1213
# Epoch 26/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1265 - val_loss: 0.1218
# Epoch 27/600
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1218 - val_loss: 0.1152
# Epoch 28/600
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1225 - val_loss: 0.1154
# Epoch 29/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1150 - val_loss: 0.1116
# Epoch 30/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1118 - val_loss: 0.1085
# Epoch 31/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1059 - val_loss: 0.1137
# Epoch 32/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1024 - val_loss: 0.1036
# Epoch 33/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1011 - val_loss: 0.1042
# Epoch 34/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0973 - val_loss: 0.1030
# Epoch 35/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0942 - val_loss: 0.1019
# Epoch 36/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0923 - val_loss: 0.1034
# Epoch 37/600
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0897 - val_loss: 0.0982
# Epoch 38/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0926 - val_loss: 0.0976
# Epoch 39/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0920 - val_loss: 0.1011
# Epoch 40/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0832 - val_loss: 0.1005
# Epoch 41/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0815 - val_loss: 0.0949
# Epoch 42/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0807 - val_loss: 0.1004
# Epoch 43/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0802 - val_loss: 0.0944
# Epoch 44/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0798 - val_loss: 0.0965
# Epoch 45/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0750 - val_loss: 0.0927
# Epoch 46/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0764 - val_loss: 0.0947
# Epoch 47/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0722 - val_loss: 0.0938
# Epoch 48/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0739 - val_loss: 0.0954
# Epoch 49/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0734 - val_loss: 0.0993
# Epoch 50/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0790 - val_loss: 0.0912
# Epoch 51/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0820 - val_loss: 0.0999
# Epoch 52/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0677 - val_loss: 0.0893
# Epoch 53/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0693 - val_loss: 0.0962
# Epoch 54/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0668 - val_loss: 0.0921
# Epoch 55/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0663 - val_loss: 0.0915
# Epoch 56/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0645 - val_loss: 0.0925
# Epoch 57/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0641 - val_loss: 0.0934
# Epoch 58/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0635 - val_loss: 0.0912
# Epoch 59/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0628 - val_loss: 0.0906
# Epoch 60/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0626 - val_loss: 0.0897
# Epoch 61/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0624 - val_loss: 0.0910
# Epoch 62/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0635 - val_loss: 0.0920
# Epoch 63/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0612 - val_loss: 0.0913
# Epoch 64/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0594 - val_loss: 0.0929
# Epoch 65/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0596 - val_loss: 0.0936
# Epoch 66/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0618 - val_loss: 0.0890
# Epoch 67/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0588 - val_loss: 0.0921
# Epoch 68/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0578 - val_loss: 0.0942
# Epoch 69/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0583 - val_loss: 0.0917
# Epoch 70/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0573 - val_loss: 0.0903
# Epoch 71/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0565 - val_loss: 0.0937
# Epoch 72/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0561 - val_loss: 0.0888
# Epoch 73/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0576 - val_loss: 0.0913
# Epoch 74/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0565 - val_loss: 0.0921
# Epoch 75/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0568 - val_loss: 0.0919
# Epoch 76/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0552 - val_loss: 0.0897
# Epoch 77/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0547 - val_loss: 0.0920
# Epoch 78/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0574 - val_loss: 0.0919
# Epoch 79/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0535 - val_loss: 0.0891
# Epoch 80/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0543 - val_loss: 0.0952
# Epoch 81/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0541 - val_loss: 0.0934
# Epoch 82/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0526 - val_loss: 0.0949
# Epoch 83/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0533 - val_loss: 0.0936
# Epoch 84/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0552 - val_loss: 0.0951
# Epoch 85/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0538 - val_loss: 0.0928
# Epoch 86/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0558 - val_loss: 0.0910
# Epoch 87/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0539 - val_loss: 0.1007
# Epoch 88/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0544 - val_loss: 0.0945
# Epoch 89/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0514 - val_loss: 0.0924
# Epoch 90/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0543 - val_loss: 0.0986
# Epoch 91/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0519 - val_loss: 0.0909
# Epoch 92/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0513 - val_loss: 0.0937
# Epoch 93/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0513 - val_loss: 0.0945
# Epoch 94/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0503 - val_loss: 0.0944
# Epoch 95/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0504 - val_loss: 0.0937
# Epoch 96/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0496 - val_loss: 0.0960
# Epoch 97/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0497 - val_loss: 0.0952
# Epoch 97: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))
model.add(Dropout(0.5))


model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))

# BINARY CLASSIFICATION
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 2s 32ms/step - loss: 0.7087 - val_loss: 0.6842
# Epoch 2/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6859 - val_loss: 0.6745
# Epoch 3/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6819 - val_loss: 0.6659
# Epoch 4/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6566 - val_loss: 0.6557
# Epoch 5/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6473 - val_loss: 0.6349
# Epoch 6/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6322 - val_loss: 0.6088
# Epoch 7/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6127 - val_loss: 0.5832
# Epoch 8/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5859 - val_loss: 0.5510
# Epoch 9/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5723 - val_loss: 0.5195
# Epoch 10/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5666 - val_loss: 0.4893
# Epoch 11/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5222 - val_loss: 0.4538
# Epoch 12/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4914 - val_loss: 0.4212
# Epoch 13/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.4676 - val_loss: 0.3906
# Epoch 14/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4469 - val_loss: 0.3596
# Epoch 15/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4155 - val_loss: 0.3313
# Epoch 16/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3929 - val_loss: 0.3087
# Epoch 17/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3762 - val_loss: 0.2871
# Epoch 18/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3652 - val_loss: 0.2630
# Epoch 19/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3674 - val_loss: 0.2427
# Epoch 20/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3393 - val_loss: 0.2315
# Epoch 21/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.3180 - val_loss: 0.2253
# Epoch 22/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3279 - val_loss: 0.2133
# Epoch 23/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3368 - val_loss: 0.2022
# Epoch 24/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2880 - val_loss: 0.1956
# Epoch 25/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2955 - val_loss: 0.1831
# Epoch 26/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2588 - val_loss: 0.1737
# Epoch 27/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2603 - val_loss: 0.1660
# Epoch 28/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2547 - val_loss: 0.1767
# Epoch 29/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2401 - val_loss: 0.1539
# Epoch 30/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2534 - val_loss: 0.1508
# Epoch 31/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2394 - val_loss: 0.1435
# Epoch 32/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2346 - val_loss: 0.1385
# Epoch 33/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2241 - val_loss: 0.1401
# Epoch 34/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2494 - val_loss: 0.1343
# Epoch 35/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2105 - val_loss: 0.1287
# Epoch 36/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2263 - val_loss: 0.1242
# Epoch 37/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2072 - val_loss: 0.1287
# Epoch 38/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2258 - val_loss: 0.1238
# Epoch 39/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1730 - val_loss: 0.1143
# Epoch 40/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2016 - val_loss: 0.1165
# Epoch 41/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2063 - val_loss: 0.1140
# Epoch 42/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1939 - val_loss: 0.1113
# Epoch 43/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1868 - val_loss: 0.1123
# Epoch 44/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1933 - val_loss: 0.1061
# Epoch 45/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1674 - val_loss: 0.1067
# Epoch 46/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1733 - val_loss: 0.1064
# Epoch 47/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1782 - val_loss: 0.1029
# Epoch 48/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1701 - val_loss: 0.1010
# Epoch 49/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1676 - val_loss: 0.1000
# Epoch 50/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1741 - val_loss: 0.1014
# Epoch 51/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1651 - val_loss: 0.1049
# Epoch 52/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1607 - val_loss: 0.0969
# Epoch 53/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1845 - val_loss: 0.0988
# Epoch 54/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1523 - val_loss: 0.1075
# Epoch 55/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1602 - val_loss: 0.0938
# Epoch 56/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1676 - val_loss: 0.0949
# Epoch 57/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1387 - val_loss: 0.0966
# Epoch 58/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1424 - val_loss: 0.0909
# Epoch 59/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1360 - val_loss: 0.0860
# Epoch 60/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1729 - val_loss: 0.0911
# Epoch 61/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1570 - val_loss: 0.0951
# Epoch 62/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1495 - val_loss: 0.0898
# Epoch 63/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1400 - val_loss: 0.0997
# Epoch 64/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1345 - val_loss: 0.0970
# Epoch 65/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1383 - val_loss: 0.0946
# Epoch 66/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1140 - val_loss: 0.0917
# Epoch 67/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1284 - val_loss: 0.0925
# Epoch 68/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1245 - val_loss: 0.0889
# Epoch 69/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1381 - val_loss: 0.0862
# Epoch 70/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1384 - val_loss: 0.0870
# Epoch 71/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1204 - val_loss: 0.0843
# Epoch 72/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1584 - val_loss: 0.0947
# Epoch 73/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1230 - val_loss: 0.0946
# Epoch 74/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1201 - val_loss: 0.0821
# Epoch 75/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1257 - val_loss: 0.0882
# Epoch 76/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1060 - val_loss: 0.0878
# Epoch 77/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1001 - val_loss: 0.0856
# Epoch 78/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1181 - val_loss: 0.0802
# Epoch 79/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1359 - val_loss: 0.0809
# Epoch 80/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1062 - val_loss: 0.0806
# Epoch 81/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1045 - val_loss: 0.0887
# Epoch 82/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0985 - val_loss: 0.0846
# Epoch 83/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1189 - val_loss: 0.0803
# Epoch 84/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1070 - val_loss: 0.0849
# Epoch 85/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1262 - val_loss: 0.1111
# Epoch 86/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1102 - val_loss: 0.0820
# Epoch 87/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0957 - val_loss: 0.0780
# Epoch 88/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0962 - val_loss: 0.0812
# Epoch 89/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0928 - val_loss: 0.0872
# Epoch 90/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1013 - val_loss: 0.0826
# Epoch 91/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.1285 - val_loss: 0.0853
# Epoch 92/600
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1025 - val_loss: 0.0858
# Epoch 93/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1017 - val_loss: 0.0925
# Epoch 94/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1069 - val_loss: 0.0861
# Epoch 95/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0993 - val_loss: 0.0932
# Epoch 96/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1047 - val_loss: 0.0847
# Epoch 97/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1020 - val_loss: 0.0856
# Epoch 98/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0900 - val_loss: 0.0911
# Epoch 99/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1080 - val_loss: 0.0952
# Epoch 100/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1116 - val_loss: 0.0892
# Epoch 101/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0973 - val_loss: 0.0964
# Epoch 102/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1023 - val_loss: 0.0935
# Epoch 103/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1100 - val_loss: 0.0835
# Epoch 104/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1055 - val_loss: 0.0849
# Epoch 105/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1045 - val_loss: 0.0936
# Epoch 106/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0912 - val_loss: 0.0891
# Epoch 107/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0878 - val_loss: 0.0979
# Epoch 108/600
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1039 - val_loss: 0.0807
# Epoch 109/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1069 - val_loss: 0.0881
# Epoch 110/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0897 - val_loss: 0.0876
# Epoch 111/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0862 - val_loss: 0.0833
# Epoch 112/600
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0847 - val_loss: 0.0858
# Epoch 112: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
pred_prob = model.predict(X_test)
predictions = (pred_prob > 0.5).astype(int)
# Out:
# 5/5 [==============================] - 0s 4ms/step

# %%
predictions = predictions.flatten()

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
# https://en.wikipedia.org/wiki/Precision_and_recall
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.99      0.98      0.98        88
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.98      0.98       143
# weighted avg       0.98      0.98      0.98       143

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[54  1]
#  [ 2 86]]
