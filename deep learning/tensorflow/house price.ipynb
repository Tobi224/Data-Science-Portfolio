# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/kc_house_data.csv')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# C:\Users\hypem\AppData\Local\Temp\ipykernel_7456\4141105712.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df['price'].mode()
# Out:
# 0    350000.0
# 1    450000.0
# Name: price, dtype: float64

# %%
df[df['price'] == 450000]
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 48     9215400105   4/28/2015  450000.0         3       1.75         1250
# 276    9189700045   1/27/2015  450000.0         3       2.00         2290
# 376    9423400140    6/9/2014  450000.0         3       1.75         1640
# 406    7821200390    8/6/2014  450000.0         3       2.00         1290
# 773    1623300160    5/6/2014  450000.0         2       2.00         1100
# ...           ...         ...       ...       ...        ...          ...
# 21004  9826701201    2/9/2015  450000.0         2       1.50         1530
# 21106  2708450020   9/12/2014  450000.0         4       2.50         3236
# 21136  9268850290    3/6/2015  450000.0         3       2.25         1620
# 21182  4140940130  11/21/2014  450000.0         3       2.75         2240
# 21440  3362401761   2/25/2015  450000.0         2       1.50         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df[(df['bedrooms'] == 9) & (df['price'] == 450000)]
# Out:
#              id       date     price  bedrooms  bathrooms  sqft_living  \
# 8537  424049043  8/11/2014  450000.0         9        7.5         4050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 8537      6504     2.0           0     0  ...      7        4050
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8537              0      1996             0    98144  47.5923 -122.301
#
#       sqft_living15  sqft_lot15
# 8537           1448        3866
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(12,8))  # Set the figure size
sns.countplot(data=df, x='bedrooms')
plt.title('Count of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.show()

# %%
# Print the value counts of bedrooms to verify your data
print(df['bedrooms'].value_counts().sort_index())
# Out:
# 1      196
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
sns.countplot(data=df,x='bedrooms',palette='husl',hue='bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='price', y='sqft_living')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
sns.scatterplot(data=df,x='price',y='lat')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
sns.scatterplot(data=df,x='long',y='lat',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
len(df)*0.01
# Out:
# 215.97

# %%
bottom_99_perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=bottom_99_perc,hue='price',edgecolor=None,alpha=0.2, palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df[df['waterfront'] == 1]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 49      822039084   3/11/2015  1350000.0         3       2.50         2753
# 230    8096000060   4/13/2015   655000.0         2       1.75         1450
# 246    2025069065   9/29/2014  2400000.0         4       2.50         3650
# 264    2123039032  10/27/2014   369900.0         1       0.75          760
# 300    3225069065   6/24/2014  3080000.0         4       5.00         4550
# ...           ...         ...        ...       ...        ...          ...
# 19968  2025069140   3/17/2015  1900000.0         3       2.50         2830
# 20309   518500480   8/11/2014  3000000.0         3       3.50         4410
# 20751  8043700105   4/17/2015  2300000.0         4       4.00         4360
# 21185   518500460   10/8/2014  2230000.0         3       3.50         3760
# 21560  9253900271    1/7/2015  3570000.0         5       4.50         4850
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
sns.boxplot(x='waterfront', y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.drop('id',axis=1)
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda year: year.year) 
'''this lambda expression is the same thing as 
                                                        def year_extraction(date):
                                                        return date.year'''
# Out:
# 'this lambda expression is the same thing as \n                                                        def year_extraction(date):\n                                                        return date.year'

# %%
df['month'] = df['date'].apply(lambda month: month.month)

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df,hue='month',palette='rainbow')
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# C:\Users\hypem\AppData\Local\Temp\ipykernel_7456\3834763391.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('month').mean()['price'].plot()
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# C:\Users\hypem\AppData\Local\Temp\ipykernel_7456\366114082.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('year').mean()['price'].plot()
# <Axes: xlabel='year'>

# %%
df = df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=101,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
'''import matplotlib.pyplot as plt

# Training data
salaries = np.array([50000, 60000, 75000, 45000])
experience = np.array([3, 5, 8, 2])

plt.figure(figsize=(12, 4))

# Original data
plt.subplot(131)
plt.scatter(experience, salaries)
plt.title('Original Data')

# Correctly scaled (using training parameters)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(np.column_stack([salaries, experience]))
plt.subplot(132)
plt.scatter(scaled_data[:, 1], scaled_data[:, 0])
plt.title('Correctly Scaled')

# New data point (65000, 6)
new_point = np.array([[65000, 6]])
scaled_new = scaler.transform(new_point)
plt.scatter(scaled_new[0, 1], scaled_new[0, 0], color='red')

plt.tight_layout()
plt.show()
'''
# Out:
# "import matplotlib.pyplot as plt\n\n# Training data\nsalaries = np.array([50000, 60000, 75000, 45000])\nexperience = np.array([3, 5, 8, 2])\n\nplt.figure(figsize=(12, 4))\n\n# Original data\nplt.subplot(131)\nplt.scatter(experience, salaries)\nplt.title('Original Data')\n\n# Correctly scaled (using training parameters)\nscaler = StandardScaler()\nscaled_data = scaler.fit_transform(np.column_stack([salaries, experience]))\nplt.subplot(132)\nplt.scatter(scaled_data[:, 1], scaled_data[:, 0])\nplt.title('Correctly Scaled')\n\n# New data point (65000, 6)\nnew_point = np.array([[65000, 6]])\nscaled_new = scaler.transform(new_point)\nplt.scatter(scaled_new[0, 1], scaled_new[0, 0], color='red')\n\nplt.tight_layout()\nplt.show()\n"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 20)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,
         validation_data=(X_test,y_test),
         batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 5s 12ms/step - loss: 430236663808.0000 - val_loss: 418891923456.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 9ms/step - loss: 428771475456.0000 - val_loss: 413710647296.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 10ms/step - loss: 407757029376.0000 - val_loss: 365868384256.0000
# Epoch 4/400
# 119/119 [==============================] - 1s 10ms/step - loss: 310084796416.0000 - val_loss: 217840779264.0000
# Epoch 5/400
# 119/119 [==============================] - 1s 10ms/step - loss: 154644463616.0000 - val_loss: 104671232000.0000
# Epoch 6/400
# 119/119 [==============================] - 1s 8ms/step - loss: 103353597952.0000 - val_loss: 97798193152.0000
# Epoch 7/400
# 119/119 [==============================] - 1s 9ms/step - loss: 100428619776.0000 - val_loss: 96142630912.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 4ms/step

# %%
mean_squared_error(y_test,predictions)
# Out:
# 26075081256.185143

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 100294.02492525078

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8033835670760399

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test, 'r')
plt.plot(y_test,predictions)

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   263000018  360000.0         3       2.50         1530      1131
# 21593  6600060120  400000.0         4       2.50         2310      5813
# 21594  1523300141  402101.0         2       0.75         1020      1350
# 21595   291310100  400000.0         3       2.50         1600      2388
# 21596  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
single_house.shape
# Out:
# (20,)

# %%
single_house = scaler.transform(single_house.values.reshape(-1,20))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# array([[284251.75]], dtype=float32)

# %%
df.head(1)
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3        1.0         1180      5650     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
#
#    yr_renovated      lat     long  sqft_living15  sqft_lot15  year  month
# 0             0  47.5112 -122.257           1340        5650  2014     10
#
# [1 rows x 21 columns]

# %%
single_house = scaler.transform(single_house.reshape(-1,20))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[1.868632e+08]], dtype=float32)

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# 'nvcc' is not recognized as an internal or external command,
# operable program or batch file.
# Thu May 15 09:16:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.83                 Driver Version: 572.83         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   42C    P8              1W /   75W |     413MiB /   8188MiB |      0%      Default |
# ...
